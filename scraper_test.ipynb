# %%
import random
from time import sleep

import undetected_chromedriver as uc

from scrape.utils import filter_html
from scrape.utils import get_listings
from scrape.utils import get_page_count
from scrape.utils import make_page_urls
from scrape.utils import get_all_listings

from scrape.constants import FREGUESIA_URL

# %%
# 1. open driver load first page


driver = uc.Chrome()
driver.get(FREGUESIA_URL)
sleep(3)
raw_html = driver.page_source

# %%
# 2. get page count
# make urls

pages = get_page_count(raw_html)
urls = make_page_urls(pages, FREGUESIA_URL)

# %%
# 3. get listings

listings_list = get_all_listings(urls, driver)

# %%
# 4. filter listings

listings = filter_html(listings_list[0])

# %%
print(listings)
# Out:
# [{'id': '34947151', 'price': '1.475€/mês', 'title': 'Apartamento T1,  Calçada da Boa Hora, 152, Boa Hora, Ajuda', 'extra': [<span class="item-detail">T1 </span>, <span class="item-detail">50 m² área bruta</span>, <span class="item-detail">1º andar sem elevador</span>, <span class="item-detail txt-highlight-red">3 horas</span>]}, {'id': '33919438', 'price': '1.400€/mês', 'title': 'Apartamento T1 na Rua Laranjal, 54, Calçada da Ajuda - Belém, Ajuda', 'extra': [<span class="item-detail">T1 </span>, <span class="item-detail">55 m² área bruta</span>, <span class="item-detail">Rés do chão sem elevador</span>]}, {'id': '34946253', 'price': '1.650€/mês', 'title': 'Apartamento T2 na Rua da Bica do Marquês, 43, Centro da Ajuda, Ajuda', 'extra': [<span class="item-detail">T2 </span>, <span class="item-detail">72 m² área bruta</span>, <span class="item-detail">1º andar sem elevador</span>, <span class="item-detail txt-highlight-red">7 horas</span>]}, {'id': '34943627', 'price': '1.550€/mês', 'title': 'Apartamento T2 na Rua General José Paulo Fernandes, Centro da Ajuda, Ajuda', 'extra': [<span class="item-detail">T2 </span>, <span class="item-detail">71 m² área bruta</span>, <span class="item-detail"> com elevador</span>, <span class="item-detail">Ontem </span>]}, {'id': '34942778', 'price': '970€/mês', 'title': 'Apartamento T0 no Beco João Alves, 2, Rio Seco - Casalinho, Ajuda', 'extra': [<span class="item-detail">T0 </span>, <span class="item-detail">40 m² área bruta</span>, <span class="item-detail"> sem elevador</span>, <span class="item-detail">Ontem </span>]}, {'id': '34520120', 'price': '1.000€/mês', 'title': 'Duplex na Rua do Mirador, 70, Boa Hora, Ajuda', 'extra': [<span class="item-detail">T1 </span>, <span class="item-detail">50 m² área bruta</span>, <span class="item-detail">1º andar sem elevador</span>, <span class="item-detail">14 abr </span>]}, {'id': '33985483', 'price': '1.400€/mês', 'title': 'Apartamento T1,  Calçada da Ajuda, s/n, Calçada da Ajuda - Belém, Ajuda', 'extra': [<span class="item-detail">T1 </span>, <span class="item-detail">70 m² área bruta</span>, <span class="item-detail">Cave sem elevador</span>]}, {'id': '34900844', 'price': '1.650€/mês', 'title': 'Apartamento T2,  Calçada do Galvão, 58, Calçada da Ajuda - Belém, Ajuda', 'extra': [<span class="item-detail">T2 </span>, <span class="item-detail">75 m² área bruta</span>, <span class="item-detail">1º andar sem elevador</span>]}, {'id': '34931886', 'price': '1.000€/mês', 'title': 'Apartamento T1 na Rua Aliança Operária, 66, Boa Hora, Ajuda', 'extra': [<span class="item-detail">T1 </span>, <span class="item-detail">40 m² área bruta</span>, <span class="item-detail">1º andar sem elevador</span>, <span class="item-detail">10 abr </span>]}, {'id': '34847198', 'price': '4.850€/mês', 'title': 'Apartamento T3 na Rua General João de Almeida, 2, Calçada da Ajuda - Belém, Ajuda', 'extra': [<span class="item-detail">Garagem incluída </span>, <span class="item-detail">T3 </span>, <span class="item-detail">168 m² área bruta</span>, <span class="item-detail">3º andar com elevador</span>]}, {'id': '34916909', 'price': '4.100€/mês', 'title': 'Apartamento T3 em Calçada da Ajuda - Belém, Ajuda', 'extra': [<span class="item-detail">Garagem incluída </span>, <span class="item-detail">T3 </span>, <span class="item-detail">165 m² área bruta</span>, <span class="item-detail"> com elevador</span>]}, {'id': '33508292', 'price': '1.500€/mês', 'title': 'Apartamento T2 na Travessa da Madressilva, Calçada da Ajuda - Belém, Ajuda', 'extra': [<span class="item-detail">T2 </span>, <span class="item-detail">50 m² área bruta</span>, <span class="item-detail">Rés do chão sem elevador</span>]}, {'id': '34932250', 'price': '1.100€/mês', 'title': 'Apartamento T2 na Travessa Dom Vasco, Centro da Ajuda, Ajuda', 'extra': [<span class="item-detail">T2 </span>, <span class="item-detail">63 m² área bruta</span>, <span class="item-detail">2º andar sem elevador</span>, <span class="item-detail">10 abr </ ...

# %%
import sqlite3

# %%
conn = sqlite3.connect("listings.db")
cursor = conn.cursor()

# %%
cursor.execute("""
    CREATE TABLE IF NOT EXISTS listings (
        id TEXT PRIMARY KEY,
        price TEXT,
        title TEXT
    )
""")

# %%
cursor.execute("INSERT INTO listings VALUES (?, ?, ?)", ("123", "500€", "Nice flat"))

# %%
# cursor.execute("INSERT INTO listings VALUES (?, ?, ?)", ("123", "500€", "Nice flat"))

# cursor.executemany("INSERT INTO listings VALUES (?, ?, ?)", list_of_tuples)

# 5. Commit (saves changes)
conn.commit()

# %%
cursor.execute("SELECT * FROM listings")

# %%
rows = cursor.fetchall()

# %%
rows
# Out:
# [('123', '500€', 'Nice flat')]
